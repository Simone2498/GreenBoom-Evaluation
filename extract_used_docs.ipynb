# %%
import os
import shutil
from pathlib import Path
from difflib import SequenceMatcher
import re

# Define paths
TMP_FILE = 'tmp2.txt'
SOURCE_DIR = 'assets/Norme'
DEST_DIR = 'assets/Utili'

# Create destination directory if it doesn't exist
os.makedirs(DEST_DIR, exist_ok=True)

print(f"Source directory: {SOURCE_DIR}")
print(f"Destination directory: {DEST_DIR}")
print(f"Target file list: {TMP_FILE}")
# Out:
# Source directory: assets/Norme
# Destination directory: assets/Utili
# Target file list: tmp2.txt

# %%
# Read target file names from tmp2.txt
with open(TMP_FILE, 'r', encoding='utf-8') as f:
    target_names = [line.strip() for line in f.readlines() if line.strip()]

# Remove duplicates and clean up
target_names = list(set(target_names))
print(f"Found {len(target_names)} unique target file names/patterns")
print("\nSample target names:")
for name in target_names[:10]:
    print(f"  - {name}")
# Out:
# Found 30 unique target file names/patterns
#
# Sample target names:
#   - D.Lgs. 116/2020"
#   - Norme\Giorgia\ADR 2025 (1).pdf
#   - Norme\Giorgia\D.M_protocollo 194 del 07-08-2023.pdf
#   - UNI EN ISO 14001:2025
#   - Reg. 1013/06"
#   - -
#   - DLgs 03.04.2006 n.152 - 10.09.2021
#   - "Richiesta Regione Lombardia ripresa
#   - dgr-4107_2020-AIA-Applicativo-regionale
#   - Circolare ANGA PROT.0000009.01-08-2019"

# %%
# Scan all files in the source directory
all_files = []
for root, dirs, files in os.walk(SOURCE_DIR):
    for file in files:
        if not file.startswith('.'):  # Skip hidden files
            full_path = os.path.join(root, file)
            all_files.append(full_path)

print(f"Found {len(all_files)} files in {SOURCE_DIR}")
print("\nSample files:")
for file in all_files[:5]:
    print(f"  - {file}")
# Out:
# Found 407 files in assets/Norme
#
# Sample files:
#   - assets/Norme/Sara/Riassunto p3.docx
#   - assets/Norme/Sara/Sentenza-del-10042024-n.-9655-Corte-di-Cassazione-Sezione-5.pdf
#   - assets/Norme/Sara/allegato-5-dd-n-254_2024.pdf
#   - assets/Norme/Sara/Dichiarazione PRTR 2025 (dati 2024) — Italiano.pdf
#   - assets/Norme/Sara/iso-140012015---environmental-management-systems-ita.pdf

# %%
def normalize_string(s):
    """Normalize string for better matching"""
    # Remove file extensions
    s = re.sub(r'\.(pdf|docx?|xlsx?|txt)$', '', s, flags=re.IGNORECASE)
    # Replace backslashes with forward slashes
    s = s.replace('\\', '/')
    # Remove common prefixes like "Norme/"
    s = re.sub(r'^(assets/)?Norme/', '', s, flags=re.IGNORECASE)
    # Convert to lowercase
    s = s.lower()
    # Remove extra spaces
    s = ' '.join(s.split())
    # Remove special characters except alphanumeric, spaces, and common separators
    s = re.sub(r'[^\w\s\-_./()]', '', s)
    return s

def similarity_score(s1, s2):
    """Calculate similarity between two strings"""
    return SequenceMatcher(None, s1, s2).ratio()

def find_matches(target_name, all_files, threshold=0.4):
    """
    Find matching files for a target name
    Lower threshold = more recall (finds more matches, may include false positives)
    """
    normalized_target = normalize_string(target_name)
    matches = []
    
    for file_path in all_files:
        # Extract just the filename
        filename = os.path.basename(file_path)
        # Also get the relative path from Norme
        rel_path = file_path.replace('assets/Norme/', '')
        
        # Normalize both filename and relative path for comparison
        norm_filename = normalize_string(filename)
        norm_relpath = normalize_string(rel_path)
        
        # Calculate similarity with both filename and relative path
        score_filename = similarity_score(normalized_target, norm_filename)
        score_relpath = similarity_score(normalized_target, norm_relpath)
        
        # Also check if target is contained in the file name (substring match)
        substring_match = normalized_target in norm_filename or normalized_target in norm_relpath
        
        # Use the best score
        best_score = max(score_filename, score_relpath)
        
        # Boost score if substring match
        if substring_match and len(normalized_target) > 5:
            best_score = max(best_score, 0.7)
        
        if best_score >= threshold:
            matches.append({
                'file': file_path,
                'score': best_score,
                'target': target_name
            })
    
    # Sort by score (highest first)
    matches.sort(key=lambda x: x['score'], reverse=True)
    return matches

print("Matching functions defined successfully")
# Out:
# Matching functions defined successfully

# %%
# Find matches for all target names
all_matches = []
files_to_copy = set()  # Use set to avoid duplicates

print("Finding matches for each target name...\n")

for target_name in target_names:
    if not target_name or target_name == '-':  # Skip empty or dash-only entries
        continue
    
    matches = find_matches(target_name, all_files, threshold=0.4)
    
    if matches:
        all_matches.extend(matches)
        # Add files to copy set
        for match in matches:
            files_to_copy.add(match['file'])
        
        # Print first few matches for this target
        print(f"Target: '{target_name}'")
        print(f"  Found {len(matches)} match(es):")
        for match in matches[:3]:  # Show top 3 matches
            print(f"    - {os.path.basename(match['file'])} (score: {match['score']:.2f})")
        if len(matches) > 3:
            print(f"    ... and {len(matches) - 3} more")
        print()
    else:
        print(f"Target: '{target_name}' - NO MATCHES FOUND")
        print()

print(f"\n{'='*60}")
print(f"Total unique files to copy: {len(files_to_copy)}")
print(f"Total match instances: {len(all_matches)}")
print(f"{'='*60}")
# Out:
# Finding matches for each target name...
#
# Target: 'D.Lgs. 116/2020"'
#   Found 18 match(es):
#     - D.Lgs 116_2020.pdf (score: 0.90)
#     - D.Lgs 116_2020 (1).pdf (score: 0.79)
#     - D.lgs.151_20.pdf (score: 0.74)
#     ... and 15 more
#
# Target: 'Norme\Giorgia\ADR 2025 (1).pdf'
#   Found 112 match(es):
#     - ADR 2025 (1).pdf (score: 1.00)
#     - ADR 2021.pdf (score: 0.89)
#     - ADR 2023 PROTETTO.pdf (score: 0.71)
#     ... and 109 more
#
# Target: 'Norme\Giorgia\D.M_protocollo 194 del 07-08-2023.pdf'
#   Found 77 match(es):
#     - D.M_protocollo 194 del 07-08-2023.pdf (score: 1.00)
#     - Circolare_protocollo_13921 del 14-05-2024.pdf (score: 0.71)
#     - 124-Del3_26.07.2023.pdf (score: 0.56)
#     ... and 74 more
#
# Target: 'UNI EN ISO 14001:2025'
#   Found 9 match(es):
#     - ISO 14001_2015.pdf (score: 0.71)
#     - 1_ISO14001.pdf (score: 0.53)
#     - Requisiti e Struttura della ISO 14001.pdf (score: 0.49)
#     ... and 6 more
#
# Target: 'Reg. 1013/06"'
#   Found 6 match(es):
#     - Reg. 1013_2006 aggiornato.pdf (score: 0.59)
#     - Regolamento 1013_2006_EN.pdf (score: 0.56)
#     - Regolamento 1013_2006_IT.pdf (score: 0.56)
#     ... and 3 more
#
# Target: 'DLgs 03.04.2006 n.152 - 10.09.2021'
#   Found 9 match(es):
#     - DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 1.00)
#     - DGR10.02.2012 - VIII 11348.pdf (score: 0.50)
#     - DGR 20.12.2013 - n. X1119.pdf (score: 0.47)
#     ... and 6 more
#
# Target: '"Richiesta Regione Lombardia ripresa'
#   Found 12 match(es):
#     - TAR Lombardia.pdf (score: 0.54)
#     - Regolamento Regionale 24 marzo 2006.pdf (score: 0.46)
#     - Presentazione novità ADR 2023_Dispensa 11 ottobre.pdf (score: 0.45)
#     ... and 9 more
#
# Target: 'dgr-4107_2020-AIA-Applicativo-regionale'
#   Found 5 match(es):
#     - dgr-4107_2020-AIA-Applicativo-regionale.pdf (score: 1.00)
#     - Programma+Energeico+Ambientale+Regionale.pdf (score: 0.45)
#     - AT_AIA_SOLID_CASTEGNATO.pdf (score: 0.43)
#     ... and 2 more
#
# Target: 'Circolare ANGA PROT.0000009.01-08-2019"'
#   Found 5 match(es):
#     - Circolare_protocollo_13921 del 14-05-2024.pdf (score: 0.51)
#     - Copia con segnatura Prot.N.0002859-2025.pdf (score: 0.47)
#     - circolare_21_01_2019_stoccaggi.pdf (score: 0.44)
#     ... and 2 more
#
# Target: 'Legge n. 147 del 2013'
#   Found 16 match(es):
#     - Legge n. 147_2013.pdf (score: 0.84)
#     - legge 70 del 25 gennaio 1994.pdf (score: 0.57)
#     - DGR 196 del 22_06_2005.pdf (score: 0.47)
#     ... and 13 more
#
# Target: 'Consenso Regione Lombardia'
#   Found 7 match(es):
#     - Convenzione Basilea.pdf (score: 0.62)
#     - TAR Lombardia.pdf (score: 0.56)
#     - Regolamento Regionale 24 marzo 2006.pdf (score: 0.52)
#     ... and 4 more
#
# Target: '"Singoli regolamenti comunali (es. Reg. TARI Castegnato)'
#   Found 5 match(es):
#     - Regolamento TARI dal 2023.aspx.pdf (score: 0.45)
#     - Regolamento Regionale 24 marzo 2006.pdf (score: 0.42)
#     - ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf (score: 0.42)
#     ... and 2 more
#
# Target: 'DLgs 03.04.2006 n.152 - 10.09.2021 / Atto Amministrativo'
#   Found 3 match(es):
#     - DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.76)
#     - Atto Amministrativo.pdf (score: 0.51)
#     - d.lgs. n. 152_2006 (T.U. ambiente).pdf (score: 0.42)
#
# Target: 'D.Lgs. 116/2020'
#   Found 18 match(es):
#     - D.Lgs 116_2020.pdf (score: 0.90)
#     - D.Lgs 116_2020 (1).pdf (score: 0.79)
#     - D.lgs.151_20.pdf (score: 0.74)
#     ... and 15 more
#
# Target: 'Richiesta integrazioni Slovenia'
#   Found 21 match(es):
#     - Presentazione novità ADR 2025.pdf (score: 0.50)
#     - DICHIARAZIONE_DI_UTILIZZO.pdf (score: 0.50)
#     - DICHIARAZIONE_DI_AVVENUTO_UTILIZZO.pdf (score: 0.49)
#     ... and 18 more
#
# Target: 'DLgs 03.04.2006 n.152 - 10.09.2021 / ALLEGATO_VIII_alla_parte_seconda'
#   Found 2 match(es):
#     - DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.66)
#     - ALLEGATO_VIII_alla_parte_seconda.pdf (score: 0.63)
#
# Target: 'Singoli regolamenti comunali (es. Reg. TARI Castegnato)'
#   Found 5 match(es):
#     - Regolamento TARI dal 2023.aspx.pdf (score: 0.45)
#     - Regolamento Regionale 24 marzo 2006.pdf (score: 0.42)
#     - ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf (score: 0.42)
#     ... and 2 more
#
# Target: 'Sentenze (sentenza del 26 giugno 2023 n. 6266 la sezione V del Consiglio di Stato)"'
#   Found 1 match(es):
#     - Sentenza proprietario non responsabile dell'inquinamento.pdf (score: 0.41)
#
# Target: 'Reg. 1157/2024'
#   Found 21 match(es):
#     - Reg. UE 1157_2024 nuovo.pdf (score: 0.70)
#     - Legge n. 147_2013.pdf (score: 0.52)
#     - AMB 1_2024.pdf (score: 0.50)
#     ... and 18 more
#
# Target: 'Singoli regolamenti comunali (es. Reg. TARI Castegnato)"'
#   Found 5 match(es):
#     - Regolamento TARI dal 2023.aspx.pdf (score: 0.45)
#     - Regolamento Regionale 24 marzo 2006.pdf (score: 0.42)
#     - ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf (score: 0.42)
#     ... and 2 more
#
# Target: '"Consenso Regione Lombardia'
#   Found 7 match(es):
#     - Convenzione Basilea.pdf (score: 0.62)
#     - TAR Lombardia.pdf (score: 0.56)
#     - Regolamento Regionale 24 marzo 2006.pdf (score: 0.52)
#     ... and 4 more
#
# Target: '"UNI EN ISO 14001:2025'
#   Found 9 match(es):
#     - ISO 14001_2015.pdf (score: 0.71)
#     - 1_ISO14001.pdf (score: 0.53)
#     - Requisiti e Struttura della ISO 14001.pdf (score: 0.49)
#     ... and 6 more
#
# Target: 'A1:2024"'
#   Found 13 match(es):
#     - AMB 1_2024.pdf (score: 0.75)
#     - ADR 2021.pdf (score: 0.57)
#     - 6511+21+04+2017.pdf (score: 0.44)
#     ... and 10 more
#
# Target: 'dpr-59-2013'
#   Found 10 match(es):
#     - dpr-59-2013.pdf (score: 1.00)
#     - ADR 2021.pdf (score: 0.53)
#     - DPR_120_2017.pdf (score: 0.52)
#     ... and 7 more
#
# Target: 'D.lgs. 152/06  Reg. 1013'
#   Found 10 match(es):
#     - D.lgs.151_20.pdf (score: 0.57)
#     - D.Lgs 116_2020.pdf (score: 0.54)
#     - D.Lgs 116_2020 (1).pdf (score: 0.54)
#     ... and 7 more
#
# Target: '"Reg. 1013/06'
#   Found 6 match(es):
#     - Reg. 1013_2006 aggiornato.pdf (score: 0.59)
#     - Regolamento 1013_2006_EN.pdf (score: 0.56)
#     - Regolamento 1013_2006_IT.pdf (score: 0.56)
#     ... and 3 more
#
# Target: 'Norme\Giorgia\n._1912_del_02_ottobre_2007.pdf'
#   Found 75 match(es):
#     - n._1912_del_02_ottobre_2007.pdf (score: 1.00)
#     - DPR_120_2017.pdf (score: 0.58)
#     - 122-Del1_13.02.2023.pdf (score: 0.58)
#     ... and 72 more
#
# Target: 'Reg. 1013/06'
#   Found 6 match(es):
#     - Reg. 1013_2006 aggiornato.pdf (score: 0.59)
#     - Regolamento 1013_2006_EN.pdf (score: 0.56)
#     - Regolamento 1013_2006_IT.pdf (score: 0.56)
#     ... and 3 more
#
# Target: '"Legge n. 147 del 2013'
#   Found 16 match(es):
#     - Legge n. 147_2013.pdf (score: 0.84)
#     - legge 70 del 25 gennaio 1994.pdf (score: 0.57)
#     - DGR 196 del 22_06_2005.pdf (score: 0.47)
#     ... and 13 more
#
#
# ============================================================
# Total unique files to copy: 190
# Total match instances: 509
# ============================================================

# %%
# Copy files to destination directory
print("Copying files to", DEST_DIR)
print(f"{'='*60}\n")

copied_count = 0
error_count = 0

for file_path in sorted(files_to_copy):
    try:
        # Get the relative path from Norme to preserve subfolder structure
        rel_path = os.path.relpath(file_path, SOURCE_DIR)
        dest_path = os.path.join(DEST_DIR, rel_path)
        
        # Create subdirectories if needed
        os.makedirs(os.path.dirname(dest_path), exist_ok=True)
        
        # Copy the file
        shutil.copy2(file_path, dest_path)
        copied_count += 1
        print(f"✓ Copied: {rel_path}")
        
    except Exception as e:
        error_count += 1
        print(f"✗ Error copying {file_path}: {e}")

print(f"\n{'='*60}")
print(f"Successfully copied: {copied_count} files")
if error_count > 0:
    print(f"Errors: {error_count}")
print(f"{'='*60}")
# Out:
# Copying files to assets/Utili
# ============================================================
#
# ✓ Copied: Debora/04 Decreto di autorizzazione prot0002856-2025.pdf
# ✓ Copied: Debora/ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf
# ✓ Copied: Debora/ALLEGATO_VIII_alla_parte_seconda.pdf
# ✓ Copied: Debora/ARPA Lombardia Indicazioni modelli dispersione contam.pdf
# ✓ Copied: Debora/AT_AIA_SOLID_CASTEGNATO.pdf
# ✓ Copied: Debora/Atto Amministrativo.pdf
# ✓ Copied: Debora/Copia con segnatura Prot.N.0002859-2025.pdf
# ✓ Copied: Debora/D.Lgs 116_2020.pdf
# ✓ Copied: Debora/D.lgs.151_20.pdf
# ✓ Copied: Debora/DGR 196 del 22_06_2005.pdf
# ✓ Copied: Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf
# ✓ Copied: Debora/DLgs-155-del-13-08-2010.pdf
# ✓ Copied: Debora/Dgr X-4792-2016_Salute pubblica.pdf
# ✓ Copied: Debora/ISPRA MLG_109_2014.pdf
# ✓ Copied: Debora/ITALIA_DLGS_n199__08_11_2021.pdf
# ✓ Copied: Debora/Indicazioni per relazione tecnica.pdf
# ✓ Copied: Debora/Ordinanza_520_01042020.pdf
# ✓ Copied: Debora/PRESCRIZIONI GENERALI  _Emissioni in atmosfera.pdf
# ✓ Copied: Debora/Prescrizioni emissioni.pdf
# ✓ Copied: Debora/Programma+Energeico+Ambientale+Regionale.pdf
# ✓ Copied: Debora/Regolamento Regionale 24 marzo 2006.pdf
# ✓ Copied: Debora/SUP45_12-11-2021.pdf
# ✓ Copied: Debora/circolare_21_01_2019_stoccaggi.pdf
# ✓ Copied: Debora/dgr-4107_2020-AIA-Applicativo-regionale.pdf
# ✓ Copied: Debora/dgr_4423_17marzo2021.pdf
# ✓ Copied: Sara/Convenzione Basilea.pdf
# ✓ Copied: Sara/D.Lgs 116_2020 (1).pdf
# ✓ Copied: Sara/Dichiarazione PRTR 2025 (dati 2024) — Italiano.pdf
# ✓ Copied: Sara/Documentazione Economica e Finanziaria - Dettaglio Giurisprudenza.pdf
# ✓ Copied: Sara/ISO 14001_2015.pdf
# ✓ Copied: Sara/L'audit interno UNI EN ISO 9001_2015 in cinque passaggi - We Learn.pdf
# ✓ Copied: Sara/L.R. Lombardia 26 del 12.12.2003 ORSO.pdf
# ✓ Copied: Sara/Legge 25 gennaio 1994 n. 70.pdf
# ✓ Copied: Sara/Legge n. 147_2013.pdf
# ✓ Copied: Sara/Link a reg. 1013_2006 consolidato al 01.01.25 (1).pdf
# ✓ Copied: Sara/Market inerti ORSO.pdf
# ✓ Copied: Sara/PR._PART._CSQ_14001.pdf
# ✓ Copied: Sara/PRTR2025_format_v1_0.xlsx
# ✓ Copied: Sara/REACH in breve.pdf
# ✓ Copied: Sara/REG._MS.pdf
# ✓ Copied: Sara/RENTRI_con sanzioni.pdf
# ✓ Copied: Sara/Reg 2024_2571_cert art. 15.pdf
# ✓ Copied: Sara/Reg. 1013_2006 aggiornato.pdf
# ✓ Copied: Sara/Reg. UE 1157_2024 nuovo.pdf
# ✓ Copied: Sara/Regolamento 1013_2006_EN.pdf
# ✓ Copied: Sara/Regolamento 1013_2006_IT.pdf
# ✓ Copied: Sara/Regolamento 669_2008_IT (integra 1013).pdf
# ✓ Copied: Sara/Regolamento TARI dal 2023.aspx.pdf
# ✓ Copied: Sara/Requisiti e Struttura della ISO 14001.pdf
# ✓ Copied: Sara/allegato-1-dd-n-254_2024.pdf
# ✓ Copied: Sara/d.lgs. n. 152_2006 (T.U. ambiente).pdf
# ✓ Copied: Sara/decreto_direttoriale_19122023_251.pdf
# ✓ Copied: Sara/guida-ai-marchi-di-certificazione.pdf
# ✓ Copied: Sara/legge 70 del 25 gennaio 1994.pdf
# ✓ Copied: Sara/mase-ec-registro-decreti-r-0000097-22-09-2023-pdf.pdf
#
# ============================================================
# Successfully copied: 190 files
# ============================================================

# %%
# Summary: Show detailed matching results
print("\nDETAILED MATCHING SUMMARY")
print(f"{'='*80}\n")

# Group matches by target
from collections import defaultdict
matches_by_target = defaultdict(list)

for match in all_matches:
    matches_by_target[match['target']].append(match)

# Sort targets alphabetically
for target in sorted(matches_by_target.keys()):
    matches = matches_by_target[target]
    print(f"Target: '{target}'")
    print(f"  Matched {len(matches)} file(s):")
    for match in sorted(matches, key=lambda x: x['score'], reverse=True):
        print(f"    - {match['file'].replace('assets/Norme/', '')} (score: {match['score']:.2f})")
    print()

# Show files that were copied
print(f"\n{'='*80}")
print(f"FILES COPIED TO {DEST_DIR}:")
print(f"{'='*80}")
for file_path in sorted(files_to_copy):
    rel_path = file_path.replace('assets/Norme/', '')
    print(f"  - {rel_path}")
# Out:
# DETAILED MATCHING SUMMARY
# ================================================================================
#
# Target: '"Consenso Regione Lombardia'
#   Matched 7 file(s):
#     - Sara/Convenzione Basilea.pdf (score: 0.62)
#     - Giorgia/TAR Lombardia.pdf (score: 0.56)
#     - Debora/Regolamento Regionale 24 marzo 2006.pdf (score: 0.52)
#     - Debora/Indicazioni per relazione tecnica.pdf (score: 0.44)
#     - Giorgia/Studio definizione valori di fondo Valcamonica.pdf (score: 0.42)
#     - Sara/RENTRI_con sanzioni.pdf (score: 0.40)
#     - Giorgia/Presentazione novità ADR 2025.pdf (score: 0.40)
#
# Target: '"Legge n. 147 del 2013'
#   Matched 16 file(s):
#     - Sara/Legge n. 147_2013.pdf (score: 0.84)
#     - Sara/legge 70 del 25 gennaio 1994.pdf (score: 0.57)
#     - Debora/DGR 196 del 22_06_2005.pdf (score: 0.47)
#     - Sara/Legge 25 gennaio 1994 n. 70.pdf (score: 0.46)
#     - Giorgia/D.M_protocollo 194 del 07-08-2023.pdf (score: 0.44)
#     - Sara/Regolamento TARI dal 2023.aspx.pdf (score: 0.43)
#     - Giorgia/DGR n.8-2838 del 27 giugno 2006.pdf (score: 0.42)
#     - Giorgia/127-Del6_16.10.2023.pdf (score: 0.42)
#     - Giorgia/124-Del3_26.07.2023.pdf (score: 0.42)
#     - Giorgia/Com Naz-Del 8_12.09.2017.pdf (score: 0.42)
#     - Debora/DLgs-155-del-13-08-2010.pdf (score: 0.41)
#     - Giorgia/017-Del05_12.12.2001.pdf (score: 0.41)
#     - Giorgia/Com Naz-Del 05_03.11.2016.pdf (score: 0.41)
#     - Sara/Regolamento 1013_2006_EN.pdf (score: 0.40)
#     - Sara/Regolamento 1013_2006_IT.pdf (score: 0.40)
#     - Giorgia/Linea-Guida-SNPA-17_2018.pdf (score: 0.40)
#
# Target: '"Reg. 1013/06'
#   Matched 6 file(s):
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.59)
#     - Sara/Regolamento 1013_2006_EN.pdf (score: 0.56)
#     - Sara/Regolamento 1013_2006_IT.pdf (score: 0.56)
#     - Sara/Legge n. 147_2013.pdf (score: 0.55)
#     - Sara/REG._MS.pdf (score: 0.42)
#     - Sara/Reg. UE 1157_2024 nuovo.pdf (score: 0.40)
#
# Target: '"Richiesta Regione Lombardia ripresa'
#   Matched 12 file(s):
#     - Giorgia/TAR Lombardia.pdf (score: 0.54)
#     - Debora/Regolamento Regionale 24 marzo 2006.pdf (score: 0.46)
#     - Giorgia/Presentazione novità ADR 2023_Dispensa 11 ottobre.pdf (score: 0.45)
#     - Debora/dichiarazione_conformita_184-ter_DEF.pdf (score: 0.45)
#     - Sara/Documentazione Economica e Finanziaria - Dettaglio Giurisprudenza.pdf (score: 0.44)
#     - Giorgia/Presentazione novità ADR 2025.pdf (score: 0.44)
#     - Giorgia/DICHIARAZIONE_DI_UTILIZZO.pdf (score: 0.43)
#     - Giorgia/Studio definizione valori di fondo Valcamonica.pdf (score: 0.43)
#     - Sara/L.R. Lombardia 26 del 12.12.2003 ORSO.pdf (score: 0.42)
#     - Sara/Convenzione Basilea.pdf (score: 0.41)
#     - Giorgia/DICHIARAZIONE_DI_AVVENUTO_UTILIZZO.pdf (score: 0.41)
#     - Sara/Regolamento TARI dal 2023.aspx.pdf (score: 0.40)
#
# Target: '"Singoli regolamenti comunali (es. Reg. TARI Castegnato)'
#   Matched 5 file(s):
#     - Sara/Regolamento TARI dal 2023.aspx.pdf (score: 0.45)
#     - Debora/Regolamento Regionale 24 marzo 2006.pdf (score: 0.42)
#     - Debora/ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf (score: 0.42)
#     - Sara/Regolamento 669_2008_IT (integra 1013).pdf (score: 0.41)
#     - Debora/PRESCRIZIONI GENERALI  _Emissioni in atmosfera.pdf (score: 0.40)
#
# Target: '"UNI EN ISO 14001:2025'
#   Matched 9 file(s):
#     - Sara/ISO 14001_2015.pdf (score: 0.71)
#     - Sara/1_ISO14001.pdf (score: 0.53)
#     - Sara/Requisiti e Struttura della ISO 14001.pdf (score: 0.49)
#     - Debora/D.Lgs 116_2020.pdf (score: 0.41)
#     - Giorgia/137-Del4_20.05.2025.pdf (score: 0.41)
#     - Giorgia/134-Del1_06.03.2025.pdf (score: 0.41)
#     - Giorgia/184-Circ02_22.05.2025.pdf (score: 0.41)
#     - Debora/Copia con segnatura Prot.N.0002859-2025.pdf (score: 0.41)
#     - Sara/L'audit interno UNI EN ISO 9001_2015 in cinque passaggi - We Learn.pdf (score: 0.40)
#
# Target: 'A1:2024"'
#   Matched 13 file(s):
#     - Sara/AMB 1_2024.pdf (score: 0.75)
#     - Giorgia/ADR 2021.pdf (score: 0.57)
#     - Sara/6511+21+04+2017.pdf (score: 0.44)
#     - Giorgia/DPR_120_2017.pdf (score: 0.44)
#     - Giorgia/ADR 2025 (1).pdf (score: 0.44)
#     - Debora/ISPRA MLG_109_2014.pdf (score: 0.42)
#     - Sara/allegato-1-dd-n-254_2024.pdf (score: 0.40)
#     - Giorgia/131-Del4_19.12.2024.pdf (score: 0.40)
#     - Giorgia/128-Del1_09.04.2024.pdf (score: 0.40)
#     - Giorgia/133-Del6_19.12.2024.pdf (score: 0.40)
#     - Giorgia/130-Del3_03.12.2024.pdf (score: 0.40)
#     - Debora/D.Lgs 116_2020.pdf (score: 0.40)
#     - Debora/ita145750.pdf (score: 0.40)
#
# Target: 'Circolare ANGA PROT.0000009.01-08-2019"'
#   Matched 5 file(s):
#     - Giorgia/Circolare_protocollo_13921 del 14-05-2024.pdf (score: 0.51)
#     - Debora/Copia con segnatura Prot.N.0002859-2025.pdf (score: 0.47)
#     - Debora/circolare_21_01_2019_stoccaggi.pdf (score: 0.44)
#     - Debora/04 Decreto di autorizzazione prot0002856-2025.pdf (score: 0.43)
#     - Sara/mase-ec-registro-decreti-r-0000097-22-09-2023-pdf.pdf (score: 0.41)
#
# Target: 'Consenso Regione Lombardia'
#   Matched 7 file(s):
#     - Sara/Convenzione Basilea.pdf (score: 0.62)
#     - Giorgia/TAR Lombardia.pdf (score: 0.56)
#     - Debora/Regolamento Regionale 24 marzo 2006.pdf (score: 0.52)
#     - Debora/Indicazioni per relazione tecnica.pdf (score: 0.44)
#     - Giorgia/Studio definizione valori di fondo Valcamonica.pdf (score: 0.42)
#     - Sara/RENTRI_con sanzioni.pdf (score: 0.40)
#     - Giorgia/Presentazione novità ADR 2025.pdf (score: 0.40)
#
# Target: 'D.Lgs. 116/2020'
#   Matched 18 file(s):
#     - Debora/D.Lgs 116_2020.pdf (score: 0.90)
#     - Sara/D.Lgs 116_2020 (1).pdf (score: 0.79)
#     - Debora/D.lgs.151_20.pdf (score: 0.74)
#     - Debora/dlgs_03_12_2010_205.pdf (score: 0.53)
#     - Debora/DLgs-155-del-13-08-2010.pdf (score: 0.47)
#     - Sara/d.lgs. n. 152_2006 (T.U. ambiente).pdf (score: 0.45)
#     - Giorgia/DPR_120_2017.pdf (score: 0.44)
#     - Sara/Legge n. 147_2013.pdf (score: 0.44)
#     - Giorgia/ADR 2021.pdf (score: 0.43)
#     - Debora/DGR 196 del 22_06_2005.pdf (score: 0.43)
#     - Debora/ITALIA_DLGS_n199__08_11_2021.pdf (score: 0.42)
#     - Sara/ISO 14001_2015.pdf (score: 0.41)
#     - Giorgia/127-Del6_16.10.2023.pdf (score: 0.41)
#     - Giorgia/126-Del5_11.10.2023.pdf (score: 0.41)
#     - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.41)
#     - Sara/AMB 1_2024.pdf (score: 0.40)
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.40)
#     - Giorgia/028-Del01_11.05.2005.pdf (score: 0.40)
#
# Target: 'D.Lgs. 116/2020"'
#   Matched 18 file(s):
#     - Debora/D.Lgs 116_2020.pdf (score: 0.90)
#     - Sara/D.Lgs 116_2020 (1).pdf (score: 0.79)
#     - Debora/D.lgs.151_20.pdf (score: 0.74)
#     - Debora/dlgs_03_12_2010_205.pdf (score: 0.53)
#     - Debora/DLgs-155-del-13-08-2010.pdf (score: 0.47)
#     - Sara/d.lgs. n. 152_2006 (T.U. ambiente).pdf (score: 0.45)
#     - Giorgia/DPR_120_2017.pdf (score: 0.44)
#     - Sara/Legge n. 147_2013.pdf (score: 0.44)
#     - Giorgia/ADR 2021.pdf (score: 0.43)
#     - Debora/DGR 196 del 22_06_2005.pdf (score: 0.43)
#     - Debora/ITALIA_DLGS_n199__08_11_2021.pdf (score: 0.42)
#     - Sara/ISO 14001_2015.pdf (score: 0.41)
#     - Giorgia/127-Del6_16.10.2023.pdf (score: 0.41)
#     - Giorgia/126-Del5_11.10.2023.pdf (score: 0.41)
#     - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.41)
#     - Sara/AMB 1_2024.pdf (score: 0.40)
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.40)
#     - Giorgia/028-Del01_11.05.2005.pdf (score: 0.40)
#
# Target: 'D.lgs. 152/06  Reg. 1013'
#   Matched 10 file(s):
#     - Debora/D.lgs.151_20.pdf (score: 0.57)
#     - Debora/D.Lgs 116_2020.pdf (score: 0.54)
#     - Sara/D.Lgs 116_2020 (1).pdf (score: 0.54)
#     - Sara/d.lgs. n. 152_2006 (T.U. ambiente).pdf (score: 0.53)
#     - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.49)
#     - Giorgia/D-LGS-152_06_PARTE-QUARTA.pdf (score: 0.46)
#     - Sara/Legge n. 147_2013.pdf (score: 0.45)
#     - Debora/DLgs-155-del-13-08-2010.pdf (score: 0.43)
#     - Debora/dlgs_03_12_2010_205.pdf (score: 0.43)
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.42)
#
# Target: 'DLgs 03.04.2006 n.152 - 10.09.2021'
#   Matched 9 file(s):
#     - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 1.00)
#     - Giorgia/DGR10.02.2012 - VIII 11348.pdf (score: 0.50)
#     - Giorgia/DGR 20.12.2013 - n. X1119.pdf (score: 0.47)
#     - Debora/dlgs_03_12_2010_205.pdf (score: 0.45)
#     - Giorgia/DGR 23.12.2012 - n. IX3509 e 3910.pdf (score: 0.45)
#     - Debora/D.lgs.151_20.pdf (score: 0.43)
#     - Giorgia/137-Del4_20.05.2025 (1).pdf (score: 0.42)
#     - Giorgia/137-Del4_20.05.2025.pdf (score: 0.42)
#     - Sara/Link a reg. 1013_2006 consolidato al 01.01.25 (1).pdf (score: 0.41)
#
# Target: 'DLgs 03.04.2006 n.152 - 10.09.2021 / ALLEGATO_VIII_alla_parte_seconda'
#   Matched 2 file(s):
#     - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.66)
#     - Debora/ALLEGATO_VIII_alla_parte_seconda.pdf (score: 0.63)
#
# Target: 'DLgs 03.04.2006 n.152 - 10.09.2021 / Atto Amministrativo'
#   Matched 3 file(s):
#     - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf (score: 0.76)
#     - Debora/Atto Amministrativo.pdf (score: 0.51)
#     - Sara/d.lgs. n. 152_2006 (T.U. ambiente).pdf (score: 0.42)
#
# Target: 'Legge n. 147 del 2013'
#   Matched 16 file(s):
#     - Sara/Legge n. 147_2013.pdf (score: 0.84)
#     - Sara/legge 70 del 25 gennaio 1994.pdf (score: 0.57)
#     - Debora/DGR 196 del 22_06_2005.pdf (score: 0.47)
#     - Sara/Legge 25 gennaio 1994 n. 70.pdf (score: 0.46)
#     - Giorgia/D.M_protocollo 194 del 07-08-2023.pdf (score: 0.44)
#     - Sara/Regolamento TARI dal 2023.aspx.pdf (score: 0.43)
#     - Giorgia/DGR n.8-2838 del 27 giugno 2006.pdf (score: 0.42)
#     - Giorgia/127-Del6_16.10.2023.pdf (score: 0.42)
#     - Giorgia/124-Del3_26.07.2023.pdf (score: 0.42)
#     - Giorgia/Com Naz-Del 8_12.09.2017.pdf (score: 0.42)
#     - Debora/DLgs-155-del-13-08-2010.pdf (score: 0.41)
#     - Giorgia/017-Del05_12.12.2001.pdf (score: 0.41)
#     - Giorgia/Com Naz-Del 05_03.11.2016.pdf (score: 0.41)
#     - Sara/Regolamento 1013_2006_EN.pdf (score: 0.40)
#     - Sara/Regolamento 1013_2006_IT.pdf (score: 0.40)
#     - Giorgia/Linea-Guida-SNPA-17_2018.pdf (score: 0.40)
#
# Target: 'Norme\Giorgia\ADR 2025 (1).pdf'
#   Matched 112 file(s):
#     - Giorgia/042-Del02_15.12.2010.pdf (score: 0.50)
#     - Giorgia/017-Del05_12.12.2001.pdf (score: 0.50)
#     - Giorgia/SUP25_19-06-2012.pdf (score: 0.50)
#     - Giorgia/071-Del05_03.11.2016.pdf (score: 0.50)
#     - Giorgia/Linea-Guida-SNPA-17_2018.pdf (score: 0.50)
#     - Giorgia/073-Del02_22.02.2017.pdf (score: 0.50)
#     - Giorgia/028-Del01_11.05.2005.pdf (score: 0.50)
#     - Giorgia/178-Circ2_01.08.2023.pdf (score: 0.50)
#     - Giorgia/2024_FAST_soil-gas_Puricelli (1).pdf (score: 0.50)
#     - Giorgia/177-Circ1_14.02.2023.pdf (score: 0.50)
#     - Giorgia/129-Del2_28.06.2024_2.pdf (score: 0.49)
#     - Giorgia/180-Circ01_15.04.2024.pdf (score: 0.49)
#     - Giorgia/182-Circ03_25.11.2024.pdf (score: 0.49)
#     - Giorgia/179-Circ03_10.10.2023.pdf (score: 0.49)
#     - Giorgia/DisposizioniAlboDM120.pdf (score: 0.49)
#     - Giorgia/175-Circ09_21.11.2022.pdf (score: 0.49)
#     - Giorgia/181-Circ02_09.07.2024.pdf (score: 0.49)
#     - Giorgia/M329 Accordo-multilaterale-M329(1).pdf (score: 0.48)
#     - Giorgia/LG_MdR_bonifica_1692830911.pdf (score: 0.48)
#     - Giorgia/SCAINI_Aree20agricole_2024.pdf (score: 0.48)
#     - Giorgia/ANALISI DI RISCHIO.pdf (score: 0.48)
#     - Giorgia/lscrizione cat 4-5.docx (score: 0.48)
#     - Giorgia/FUIN_1_MLE.pdf (score: 0.47)
#     - Debora/dpr-59-2013.pdf (score: 0.47)
#     - Giorgia/044-Circ1943_22.12.2005.pdf (score: 0.47)
#     - Giorgia/FAQ_terre_rocce_scavo_2020-03-31.pdf (score: 0.47)
#     - Giorgia/Linee Guida.pdf (score: 0.46)
#     - Giorgia/ALBO - Iscrizione Cat 10.docx (score: 0.46)
#     - Giorgia/D.M_protocollo 194 del 07-08-2023.pdf (score: 0.46)
#     - Giorgia/026-Del01_30.03.2004.pdf (score: 0.46)
#     - Sara/AMB 1_2024.pdf (score: 0.46)
#     - Giorgia/lscrizione cat 9.docx (score: 0.45)
#     - Giorgia/Imballaggi vuoti.pdf (score: 0.45)
#     - Giorgia/Trasporto da diversi siti.pdf (score: 0.45)
#     - Giorgia/___ ATTO COMPLETO ___.pdf (score: 0.45)
#     - Giorgia/Materiali_di_riporto_feb2024_1707328238.pdf (score: 0.45)
#     - Giorgia/Presentazione novità ADR 2023_Dispensa 11 ottobre.pdf (score: 0.44)
#     - Giorgia/DGR n.8-2838 del 27 giugno 2006.pdf (score: 0.44)
#     - Debora/D.Lgs 116_2020.pdf (score: 0.44)
#     - Giorgia/FAST01_MOD3_ADR-_FLUXC_LUCHETTIL2024.pdf (score: 0.44)
#     - Giorgia/Mod. 2 - Ruoli e competenze.pdf (score: 0.44)
#     - Giorgia/n._1912_del_02_ottobre_2007.pdf (score: 0.44)
#     - Giorgia/presentazione-FAST-Fornetti-2024.pdf (score: 0.43)
#     - Sara/Reg 2024_2571_cert art. 15.pdf (score: 0.43)
#     - Giorgia/Software-Rome-Plus-v1_1.pdf (score: 0.43)
#     - Giorgia/Trasporto rifiuti e ADR.pdf (score: 0.43)
#     - Giorgia/Iscrizione in cat 4.docx (score: 0.43)
#     - Debora/dgr_4423_17marzo2021.pdf (score: 0.43)
#     - Sara/CELEX_32016R1245_IT_TXT (1).pdf (score: 0.42)
#     - Giorgia/Bonifica_stampa.pdf (score: 0.42)
#     - Giorgia/UsoImmediatodeiMezzi.pdf (score: 0.42)
#     - Debora/DGR 196 del 22_06_2005.pdf (score: 0.41)
#     - Giorgia/CARATTERIZZAZIONE DEL SITO.pdf (score: 0.41)
#     - Giorgia/siti-contaminati-02marzo08.pdf (score: 0.41)
#     - Sara/Competent_Authorities_EN_24_APR_2025 (2) (1).pdf (score: 0.41)
#     - Giorgia/20250331_CONAI_PSP2025_pagina_doppia.pdf (score: 0.41)
#     - Giorgia/Manuale-INAIL-2014_FAST_Berardi_2024.pdf (score: 0.41)
#     - Giorgia/manuale indagini amb. preliminari 43_2006.pdf (score: 0.41)
#     - Giorgia/Circolare_protocollo_13921 del 14-05-2024.pdf (score: 0.41)
#     - Sara/Competent_Authorities_EN_24_APR_2025 (2).pdf (score: 0.40)
#     - Sara/PRTR2025_format_v1_0.xlsx (score: 0.40)
#     - Sara/ALLEGATO+DGR+6511.pdf (score: 0.40)
#     - Giorgia/FUIN_2_VarTemp_Passivi.pdf (score: 0.40)
#     - Giorgia/DOCUMENTO_DI_TRASPORTO.pdf (score: 0.40)
#     - Giorgia/Allegati-alla-Parte-IV.pdf (score: 0.40)
#     - Debora/ISPRA MLG_109_2014.pdf (score: 0.40)
#     - Debora/direttiva 42-2001 CE.pdf (score: 0.40)
#
# Target: 'Norme\Giorgia\D.M_protocollo 194 del 07-08-2023.pdf'
#   Matched 77 file(s):
#     - Giorgia/D.M_protocollo 194 del 07-08-2023.pdf (score: 1.00)
#     - Giorgia/Circolare_protocollo_13921 del 14-05-2024.pdf (score: 0.71)
#     - Giorgia/124-Del3_26.07.2023.pdf (score: 0.56)
#     - Giorgia/115-Del3_07.02.2022.pdf (score: 0.53)
#     - Giorgia/134-Del1_06.03.2025.pdf (score: 0.53)
#     - Giorgia/125-Del4_26.07.2023.pdf (score: 0.53)
#     - Giorgia/SUP25_19-06-2012.pdf (score: 0.52)
#     - Giorgia/Com Naz-Del 05_03.11.2016.pdf (score: 0.51)
#     - Giorgia/138-Del5_20.05.2025.pdf (score: 0.50)
#     - Giorgia/137-Del4_20.05.2025.pdf (score: 0.50)
#     - Giorgia/127-Del6_16.10.2023.pdf (score: 0.50)
#     - Giorgia/122-Del1_13.02.2023.pdf (score: 0.50)
#     - Giorgia/135-Del2_06.03.2025.pdf (score: 0.50)
#     - Giorgia/126-Del5_11.10.2023.pdf (score: 0.50)
#     - Giorgia/123-Del2_13.02.2023.pdf (score: 0.50)
#     - Giorgia/128-Del1_09.04.2024.pdf (score: 0.50)
#     - Giorgia/Com Naz-Del 8_12.09.2017.pdf (score: 0.49)
#     - Giorgia/DPR_120_2017.pdf (score: 0.49)
#     - Giorgia/1_Verginelli-Software-Risknet-3.pdf (score: 0.41)
#     - Giorgia/FAQ_terre_rocce_scavo_2020-03-31 (1).pdf (score: 0.41)
#     - Giorgia/manuale indagini amb. preliminari 43_2006.pdf (score: 0.40)
#     - Giorgia/Circolare_protocollo_13921 del 14-05-2024.pdf (score: 0.40)
#     - Giorgia/Decreto_Legislativo_27_gennaio_2010__n__35.pdf (score: 0.40)
#     - Giorgia/ADR 2025 (1).pdf (score: 0.40)
#
# Target: 'Reg. 1013/06'
#   Matched 6 file(s):
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.59)
#     - Sara/Regolamento 1013_2006_EN.pdf (score: 0.56)
#     - Sara/Regolamento 1013_2006_IT.pdf (score: 0.56)
#     - Sara/Legge n. 147_2013.pdf (score: 0.55)
#     - Sara/REG._MS.pdf (score: 0.42)
#     - Sara/Reg. UE 1157_2024 nuovo.pdf (score: 0.40)
#
# Target: 'Reg. 1013/06"'
#   Matched 6 file(s):
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.59)
#     - Sara/Regolamento 1013_2006_EN.pdf (score: 0.56)
#     - Sara/Regolamento 1013_2006_IT.pdf (score: 0.56)
#     - Sara/Legge n. 147_2013.pdf (score: 0.55)
#     - Sara/REG._MS.pdf (score: 0.42)
#     - Sara/Reg. UE 1157_2024 nuovo.pdf (score: 0.40)
#
# Target: 'Reg. 1157/2024'
#   Matched 21 file(s):
#     - Sara/Reg. UE 1157_2024 nuovo.pdf (score: 0.70)
#     - Sara/Legge n. 147_2013.pdf (score: 0.52)
#     - Sara/AMB 1_2024.pdf (score: 0.50)
#     - Debora/D.Lgs 116_2020.pdf (score: 0.50)
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.46)
#     - Debora/D.lgs.151_20.pdf (score: 0.46)
#     - Giorgia/180-Circ01_15.04.2024.pdf (score: 0.46)
#     - Giorgia/182-Circ03_25.11.2024.pdf (score: 0.46)
#     - Giorgia/ADR 2021.pdf (score: 0.45)
#     - Giorgia/115-Del3_07.02.2022.pdf (score: 0.44)
#     - Sara/D.Lgs 116_2020 (1).pdf (score: 0.44)
#     - Giorgia/131-Del4_19.12.2024.pdf (score: 0.42)
#     - Giorgia/133-Del6_19.12.2024.pdf (score: 0.42)
#     - Giorgia/130-Del3_03.12.2024.pdf (score: 0.42)
#     - Sara/allegato-1-dd-n-254_2024.pdf (score: 0.42)
#     - Sara/Regolamento 1013_2006_EN.pdf (score: 0.42)
#     - Sara/Regolamento 1013_2006_IT.pdf (score: 0.42)
#     - Sara/Reg 2024_2571_cert art. 15.pdf (score: 0.40)
#     - Giorgia/183-Circ01_15.04.2025.pdf (score: 0.40)
#     - Giorgia/175-Circ09_21.11.2022.pdf (score: 0.40)
#     - Giorgia/181-Circ02_09.07.2024.pdf (score: 0.40)
#
# Target: 'Richiesta integrazioni Slovenia'
#   Matched 21 file(s):
#     - Giorgia/Presentazione novità ADR 2025.pdf (score: 0.50)
#     - Giorgia/DICHIARAZIONE_DI_UTILIZZO.pdf (score: 0.50)
#     - Giorgia/DICHIARAZIONE_DI_AVVENUTO_UTILIZZO.pdf (score: 0.49)
#     - Giorgia/informazioni-base-consulente-adr-.pdf (score: 0.47)
#     - Debora/Indicazioni per relazione tecnica.pdf (score: 0.47)
#     - Debora/Prescrizioni emissioni.pdf (score: 0.45)
#     - Sara/Market inerti ORSO.pdf (score: 0.45)
#     - Sara/Convenzione Basilea.pdf (score: 0.44)
#     - Sara/RENTRI_con sanzioni.pdf (score: 0.44)
#     - Sara/0_Introduzione.pdf (score: 0.44)
#     - Giorgia/2023.04.01 - Contaminazioni storiche_obbligo bonifica.pdf (score: 0.43)
#     - Giorgia/Trasporto da diversi siti.pdf (score: 0.43)
#     - Debora/ARPA Lombardia Indicazioni modelli dispersione contam.pdf (score: 0.43)
#     - Giorgia/Studio definizione valori di fondo Valcamonica.pdf (score: 0.42)
#     - Sara/Dichiarazione PRTR 2025 (dati 2024) — Italiano.pdf (score: 0.42)
#     - Giorgia/Verginelli_6_Esercitazione_Risk-net_1.pdf (score: 0.41)
#     - Sara/guida-ai-marchi-di-certificazione.pdf (score: 0.41)
#     - Sara/REACH in breve.pdf (score: 0.40)
#     - Giorgia/albo-gestori-ambientali-all-c-categoria-9-dotazione-personale.pdf (score: 0.40)
#     - Giorgia/DisposizioniAlboDM120.pdf (score: 0.40)
#     - Giorgia/Presentazione novità ADR 2023_Dispensa 11 ottobre.pdf (score: 0.40)
#
# Target: 'Sentenze (sentenza del 26 giugno 2023 n. 6266 la sezione V del Consiglio di Stato)"'
#   Matched 1 file(s):
#     - Giorgia/Sentenza proprietario non responsabile dell'inquinamento.pdf (score: 0.41)
#
# Target: 'Singoli regolamenti comunali (es. Reg. TARI Castegnato)'
#   Matched 5 file(s):
#     - Sara/Regolamento TARI dal 2023.aspx.pdf (score: 0.45)
#     - Debora/Regolamento Regionale 24 marzo 2006.pdf (score: 0.42)
#     - Debora/ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf (score: 0.42)
#     - Sara/Regolamento 669_2008_IT (integra 1013).pdf (score: 0.41)
#     - Debora/PRESCRIZIONI GENERALI  _Emissioni in atmosfera.pdf (score: 0.40)
#
# Target: 'Singoli regolamenti comunali (es. Reg. TARI Castegnato)"'
#   Matched 5 file(s):
#     - Sara/Regolamento TARI dal 2023.aspx.pdf (score: 0.45)
#     - Debora/Regolamento Regionale 24 marzo 2006.pdf (score: 0.42)
#     - Debora/ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf (score: 0.42)
#     - Sara/Regolamento 669_2008_IT (integra 1013).pdf (score: 0.41)
#     - Debora/PRESCRIZIONI GENERALI  _Emissioni in atmosfera.pdf (score: 0.40)
#
# Target: 'UNI EN ISO 14001:2025'
#   Matched 9 file(s):
#     - Sara/ISO 14001_2015.pdf (score: 0.71)
#     - Sara/1_ISO14001.pdf (score: 0.53)
#     - Sara/Requisiti e Struttura della ISO 14001.pdf (score: 0.49)
#     - Debora/D.Lgs 116_2020.pdf (score: 0.41)
#     - Giorgia/137-Del4_20.05.2025.pdf (score: 0.41)
#     - Giorgia/134-Del1_06.03.2025.pdf (score: 0.41)
#     - Giorgia/184-Circ02_22.05.2025.pdf (score: 0.41)
#     - Debora/Copia con segnatura Prot.N.0002859-2025.pdf (score: 0.41)
#     - Sara/L'audit interno UNI EN ISO 9001_2015 in cinque passaggi - We Learn.pdf (score: 0.40)
#
# Target: 'dgr-4107_2020-AIA-Applicativo-regionale'
#   Matched 5 file(s):
#     - Debora/dgr-4107_2020-AIA-Applicativo-regionale.pdf (score: 1.00)
#     - Debora/Programma+Energeico+Ambientale+Regionale.pdf (score: 0.45)
#     - Debora/AT_AIA_SOLID_CASTEGNATO.pdf (score: 0.43)
#     - Sara/Reg. 1013_2006 aggiornato.pdf (score: 0.41)
#     - Debora/Dgr X-4792-2016_Salute pubblica.pdf (score: 0.40)
#
# Target: 'dpr-59-2013'
#   Matched 10 file(s):
#     - Debora/dpr-59-2013.pdf (score: 1.00)
#     - Giorgia/ADR 2021.pdf (score: 0.53)
#     - Giorgia/DPR_120_2017.pdf (score: 0.52)
#     - Sara/19011-2018.pdf (score: 0.48)
#     - Giorgia/SUP25_19-06-2012.pdf (score: 0.44)
#     - Debora/SUP45_12-11-2021.pdf (score: 0.44)
#     - Giorgia/ADR 2025 (1).pdf (score: 0.43)
#     - Giorgia/DGR 2838.pdf (score: 0.42)
#     - Debora/ISPRA MLG_109_2014.pdf (score: 0.41)
#     - Debora/DLgs-155-del-13-08-2010.pdf (score: 0.41)
#
#
# ================================================================================
# FILES COPIED TO assets/Utili:
# ================================================================================
#   - Debora/04 Decreto di autorizzazione prot0002856-2025.pdf
#   - Debora/ALL 9 - Registrazione Controlli - PORTATILE uscita.pdf
#   - Debora/ALLEGATO_VIII_alla_parte_seconda.pdf
#   - Debora/ARPA Lombardia Indicazioni modelli dispersione contam.pdf
#   - Debora/AT_AIA_SOLID_CASTEGNATO.pdf
#   - Debora/Atto Amministrativo.pdf
#   - Debora/Copia con segnatura Prot.N.0002859-2025.pdf
#   - Debora/D.Lgs 116_2020.pdf
#   - Debora/D.lgs.151_20.pdf
#   - Debora/DGR 196 del 22_06_2005.pdf
#   - Debora/DLgs 03.04.2006 n.152 - 10.09.2021.pdf
#   - Debora/DLgs-155-del-13-08-2010.pdf
#   - Debora/Dgr X-4792-2016_Salute pubblica.pdf
#   - Debora/ISPRA MLG_109_2014.pdf
#   - Debora/ITALIA_DLGS_n199__08_11_2021.pdf
#   - Debora/Indicazioni per relazione tecnica.pdf
#   - Debora/Ordinanza_520_01042020.pdf
#   - Debora/PRESCRIZIONI GENERALI  _Emissioni in atmosfera.pdf
#   - Debora/Prescrizioni emissioni.pdf
#   - Debora/Programma+Energeico+Ambientale+Regionale.pdf
#   - Debora/Regolamento Regionale 24 marzo 2006.pdf
#   - Debora/SUP45_12-11-2021.pdf
#   - Debora/circolare_21_01_2019_stoccaggi.pdf
#   - Debora/dgr-4107_2020-AIA-Applicativo-regionale.pdf
#   - Debora/dgr_4423_17marzo2021.pdf
#   - Debora/dichiarazione_conformita_184-ter_DEF.pdf
#   - Debora/direttiva 42-2001 CE.pdf
#   - Debora/dlgs_03_12_2010_205.pdf
